# %%
# Regular EDA and plotting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import seaborn as sns
import warnings
import rdkit
import mols2grid
from rdkit import Chem

# PyTorch + model building
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader

# %%
# Hyperparameters
block_size = 128
max_iters = 2000
eval_interval = 100
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 300
n_embd = 384
n_head = 4
n_layer = 4
dropout = 0.2

torch.manual_seed(1337)

# %%
# Load and preprocess SMILES data
df = pd.read_csv("polymer_tg_tm.csv")
df = df.dropna(subset=["SMILES"]).copy()
df["SMILES"] = df["SMILES"].astype(str)
df = df.sample(n=1000, random_state=66).reset_index(drop=True)
smiles_list = df["SMILES"].tolist()

# Prepare data string and tokenizer
text = "\n".join(smiles_list)
chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for i, ch in enumerate(chars)}
encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join([itos[i] for i in l])

# Tokenize all text
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

# %%
df
# Out:
#                                                 SMILES     Tg     Tm
# 0                                *OC(CCCCCCC=C)CC(*)=O  -50.0   35.0
# 1    *CCCCOC(=O)NCC(F)(F)C(F)(F)C(F)(F)C(F)(F)CNC(=...   33.0  140.0
# 2    *CNC(=O)OCc1ccc(COCc2ccc(COC(=O)NCc3ccc(C(C)(C...   39.0  173.0
# 3    *CCCCCCCN1C(=O)c2ccc(C(=O)Oc3ccc(-c4ccc(OC(=O)...  117.0  290.0
# 4    *c1ccc(-c2ccc(-c3ccc4nc(Oc5cc(-c6ccccc6)c6cc(*...  308.0  480.0
# ..                                                 ...    ...    ...
# 995            *CCOCCOCCOCCOCCOCCOC(=O)NCCCCCCNC(=O)O*  -31.0   65.0
# 996  *Oc1cc(OCCOC)c(OC(=O)c2ccc(C(*)=O)cc2OCCOCC)cc...   99.0  164.0
# 997          *CCCCCCOc1ccc(/C=C/c2ccc(O*)c3ccccc23)cc1   78.0  181.0
# 998           *CCCCCCCCCCOC(=O)CCCCCCCCCCCCCCCCC(=O)O*  -17.0   92.7
# 999  *Oc1ccc(Oc2ccc(C(=O)c3cccc(C(=O)c4ccc(*)cc4)c3...  148.0  280.0
#
# [1000 rows x 3 columns]

# %%
# Dataset class
class SMILESDataset(Dataset):
    def __init__(self, data, block_size):
        self.data = data
        self.block_size = block_size

    def __len__(self):
        return len(self.data) - self.block_size

    def __getitem__(self, idx):
        x = self.data[idx:idx + self.block_size]
        y = self.data[idx + 1:idx + self.block_size + 1]
        return x, y

# %%
# Create DataLoaders
train_dataset = SMILESDataset(train_data, block_size)
val_dataset = SMILESDataset(val_data, block_size)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
# Model components
class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        wei = q @ k.transpose(-2, -1) * k.shape[-1] ** -0.5
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        return wei @ v

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(head_size * num_heads, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

class GPTLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B * T, C)
            targets = targets.view(B * T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, _ = self(idx_cond)
            logits = logits[:, -1, :]
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

# %%
# Loss estimation with DataLoader
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split, loader in [('train', train_loader), ('val', val_loader)]:
        losses = torch.zeros(eval_iters)
        for k, (X, Y) in enumerate(loader):
            if k >= eval_iters:
                break
            X, Y = X.to(device), Y.to(device)
            _, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
# Initialize model
model = GPTLanguageModel().to(device)
print(sum(p.numel() for p in model.parameters()) / 1e6, 'M parameters')

# Optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4)
# Out:
# 7.173159 M parameters

# %%
# Training loop
train_iterator = iter(train_loader)
for step in range(max_iters):
    if step % eval_interval == 0 or step == max_iters - 1:
        losses = estimate_loss()
        print(f"step {step}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    try:
        X, Y = next(train_iterator)
    except StopIteration:
        train_iterator = iter(train_loader)
        X, Y = next(train_iterator)

    X, Y = X.to(device), Y.to(device)
    logits, loss = model(X, Y)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 3.8420, val loss 1.8182
# step 100: train loss 1.4135, val loss 0.6550
# step 200: train loss 0.9949, val loss 0.4556
# step 300: train loss 0.7758, val loss 0.3650
# step 400: train loss 0.6535, val loss 0.3163
# step 500: train loss 0.5790, val loss 0.2930
# step 600: train loss 0.5124, val loss 0.2681
# step 700: train loss 0.4663, val loss 0.2524
# step 800: train loss 0.4261, val loss 0.2416
# step 900: train loss 0.4002, val loss 0.2383
# step 1000: train loss 0.3731, val loss 0.2307
# step 1100: train loss 0.3519, val loss 0.2272
# step 1200: train loss 0.3269, val loss 0.2267
# step 1300: train loss 0.3080, val loss 0.2299
# step 1400: train loss 0.2945, val loss 0.2311
# step 1500: train loss 0.2814, val loss 0.2325
# step 1600: train loss 0.2636, val loss 0.2358
# step 1700: train loss 0.2510, val loss 0.2319
# step 1800: train loss 0.2415, val loss 0.2433
# step 1900: train loss 0.2235, val loss 0.2444
# step 1999: train loss 0.2222, val loss 0.2488

# %%
# Generate monomers
context = torch.zeros((1, 1), dtype=torch.long, device=device)
generated = decode(model.generate(context, max_new_tokens=5000)[0].tolist())
smiles_list = generated.split("\n")
valid_smiles = [s for s in smiles_list if Chem.MolFromSmiles(s)]
print(f"{len(valid_smiles)} valid out of {len(smiles_list)}")
# Out:
# 43 valid out of 121
# [21:24:25] non-ring atom 4 marked aromatic
# [21:24:25] SMILES Parse Error: unclosed ring for input: '*Oc1cc(C(C)c2cccc(OC(*)=O)c2)C(F)F'
# [21:24:25] SMILES Parse Error: extra close parentheses while parsing: *CCCCCCC1SC(=O)(=O)c2ccc(C)c(OC(=O)CCCC(=O)N(*)C=O)cc2)cc1
# [21:24:25] SMILES Parse Error: check for mistakes around position 55:
# [21:24:25] )CCCC(=O)N(*)C=O)cc2)cc1
# [21:24:25] ~~~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*CCCCCCC1SC(=O)(=O)c2ccc(C)c(OC(=O)CCCC(=O)N(*)C=O)cc2)cc1' for input: '*CCCCCCC1SC(=O)(=O)c2ccc(C)c(OC(=O)CCCC(=O)N(*)C=O)cc2)cc1'
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *CCCCCC(=O)Nc1ccc(Cc2ccc(N*)cc1
# [21:24:25] SMILES Parse Error: check for mistakes around position 18:
# [21:24:25] *CCCCCC(=O)Nc1ccc(Cc2ccc(N*)cc1
# [21:24:25] ~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*CCCCCC(=O)Nc1ccc(Cc2ccc(N*)cc1' for input: '*CCCCCC(=O)Nc1ccc(Cc2ccc(N*)cc1'
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *CC(CCCCC(C)(C)C(=O)O*
# [21:24:25] SMILES Parse Error: check for mistakes around position 4:
# [21:24:25] *CC(CCCCC(C)(C)C(=O)O*
# [21:24:25] ~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*CC(CCCCC(C)(C)C(=O)O*' for input: '*CC(CCCCC(C)(C)C(=O)O*'
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *C(=O)Nc1cc2cc(C)c(c1)C(=O)c3cc2c(c1=O)N(c1ccc(Oc4ccc(N5C(=O)c6ccc(*)cc4C3=O)c2)cc1
# [21:24:25] SMILES Parse Error: check for mistakes around position 41:
# [21:24:25] 1)C(=O)c3cc2c(c1=O)N(c1ccc(Oc4ccc(N5C(=O)
# [21:24:25] ~~~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*C(=O)Nc1cc2cc(C)c(c1)C(=O)c3cc2c(c1=O)N(c1ccc(Oc4ccc(N5C(=O)c6ccc(*)cc4C3=O)c2)cc1' for input: '*C(=O)Nc1cc2cc(C)c(c1)C(=O)c3cc2c(c1=O)N(c1ccc(Oc4ccc(N5C(=O)c6ccc(*)cc4C3=O)c2)cc1'
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *CCc1ccc(Oc2ccc(N3C(=O)c4ccc(c3)C(=O)c4cc(-c5ccc6c(c5)C(=O)N(*)C6=O)cc4C3=O)cc2C1=O
# [21:24:25] SMILES Parse Error: check for mistakes around position 9:
# [21:24:25] *CCc1ccc(Oc2ccc(N3C(=O)c4ccc(c3)C(=O)c4cc
# [21:24:25] ~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*CCc1ccc(Oc2ccc(N3C(=O)c4ccc(c3)C(=O)c4cc(-c5ccc6c(c5)C(=O)N(*)C6=O)cc4C3=O)cc2C1=O' for input: '*CCc1ccc(Oc2ccc(N3C(=O)c4ccc(c3)C(=O)c4cc(-c5ccc6c(c5)C(=O)N(*)C6=O)cc4C3=O)cc2C1=O'
# [21:24:25] SMILES Parse Error: unclosed ring for input: '*CC(*)C(C)c1'
# [21:24:25] SMILES Parse Error: unclosed ring for input: '*Oc1ccc(C(COC(=O)c2ccc(OC(=O)c3c(Cc4cccc(C(*)=O)cc4)cc4)cc3)cc2)cc1'
# [21:24:25] Explicit valence for atom # 2 Si, 5, is greater than permitted
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *

# [21:24:25] SMILES Parse Error: syntax error while parsing: *N=P(*)(OCCOCC)(OC(-1c1ccc(N)c2ccccc2)c1
# [21:24:25] SMILES Parse Error: check for mistakes around position 21:
# [21:24:25] *N=P(*)(OCCOCC)(OC(-1c1ccc(N)c2ccccc2)c1
# [21:24:25] ~~~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*N=P(*)(OCCOCC)(OC(-1c1ccc(N)c2ccccc2)c1' for input: '*N=P(*)(OCCOCC)(OC(-1c1ccc(N)c2ccccc2)c1'
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *Cc1ccc(Cc2cc(NC(=O)CCCCC(*)=O)cc(-c2nnc(-c3ccccn3)o2)cc1
# [21:24:25] SMILES Parse Error: check for mistakes around position 8:
# [21:24:25] *Cc1ccc(Cc2cc(NC(=O)CCCCC(*)=O)cc(-c2nnc(
# [21:24:25] ~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*Cc1ccc(Cc2cc(NC(=O)CCCCC(*)=O)cc(-c2nnc(-c3ccccn3)o2)cc1' for input: '*Cc1ccc(Cc2cc(NC(=O)CCCCC(*)=O)cc(-c2nnc(-c3ccccn3)o2)cc1'
# [21:24:25] SMILES Parse Error: extra close parentheses while parsing: *CCCCCCCCCCCCCCCCC)NC(=O)CCCCCC(=O)N*
# [21:24:25] SMILES Parse Error: check for mistakes around position 19:
# [21:24:25] *CCCCCCCCCCCCCCCCC)NC(=O)CCCCCC(=O)N*
# [21:24:25] ~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*CCCCCCCCCCCCCCCCC)NC(=O)CCCCCC(=O)N*' for input: '*CCCCCCCCCCCCCCCCC)NC(=O)CCCCCC(=O)N*'
# [21:24:25] SMILES Parse Error: unclosed ring for input: '*CCc1cccc2c1'
# [21:24:25] Can't kekulize mol.  Unkekulized atoms: 7 8 9 10 11 25 26
# [21:24:25] Explicit valence for atom # 15 C, 5, is greater than permitted
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *SC1C(=O)OCCOc1ccc(C(*)cc1
# [21:24:25] SMILES Parse Error: check for mistakes around position 19:
# [21:24:25] *SC1C(=O)OCCOc1ccc(C(*)cc1
# [21:24:25] ~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*SC1C(=O)OCCOc1ccc(C(*)cc1' for input: '*SC1C(=O)OCCOc1ccc(C(*)cc1'
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *OC(OC(=O)c1cc(S(=O)(=Oc2ccc(OC(=O)c3ccccc3-NC)c(*)cc2C1=O
# [21:24:25] SMILES Parse Error: check for mistakes around position 4:
# [21:24:25] *OC(OC(=O)c1cc(S(=O)(=Oc2ccc(OC(=O)c3cccc
# [21:24:25] ~~~^
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *OC(OC(=O)c1cc(S(=O)(=Oc2ccc(OC(=O)c3ccccc3-NC)c(*)cc2C1=O
# [21:24:25] SMILES Parse Error: check for mistakes around position 15:
# [21:24:25] *OC(OC(=O)c1cc(S(=O)(=Oc2ccc(OC(=O)c3cccc
# [21:24:25] ~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *OC(OC(=O)c1cc(S(=O)(=Oc2ccc(OC(=O)c3ccccc3-NC)c(*)cc2C1=O
# [21:24:25] SMILES Parse Error: check for mistakes around position 21:
# [21:24:25] *OC(OC(=O)c1cc(S(=O)(=Oc2ccc(OC(=O)c3cccc
# [21:24:25] ~~~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*OC(OC(=O)c1cc(S(=O)(=Oc2ccc(OC(=O)c3ccccc3-NC)c(*)cc2C1=O' for input: '*OC(OC(=O)c1cc(S(=O)(=Oc2ccc(OC(=O)c3ccccc3-NC)c(*)cc2C1=O'
# [21:24:25] SMILES Parse Error: syntax error while parsing: *c1ccc(*)[c(i]c3ccccc2[n]1)(*)c1
# [21:24:25] SMILES Parse Error: check for mistakes around position 12:
# [21:24:25] *c1ccc(*)[c(i]c3ccccc2[n]1)(*)c1
# [21:24:25] ~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*c1ccc(*)[c(i]c3ccccc2[n]1)(*)c1' for input: '*c1ccc(*)[c(i]c3ccccc2[n]1)(*)c1'
# [21:24:25] Explicit valence for atom # 1 N, 4, is greater than permitted
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *CCCCCCCCCCCCCCCCCOC(=O)OCCN1C(=O)c2ccc(OCC
# [21:24:25] SMILES Parse Error: check for mistakes around position 40:
# [21:24:25] C(=O)OCCN1C(=O)c2ccc(OCC
# [21:24:25] ~~~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*CCCCCCCCCCCCCCCCCOC(=O)OCCN1C(=O)c2ccc(OCC' for input: '*CCCCCCCCCCCCCCCCCOC(=O)OCCN1C(=O)c2ccc(OCC'
# [21:24:25] SMILES Parse Error: extra close parentheses while parsing: *Oc1ccc(C(=O)OC(=O)c2cccc(O*)cc2)cc1C)cc1
# [21:24:25] SMILES Parse Error: check for mistakes around position 38:
# [21:24:25] O)c2cccc(O*)cc2)cc1C)cc1
# [21:24:25] ~~~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*Oc1ccc(C(=O)OC(=O)c2cccc(O*)cc2)cc1C)cc1' for input: '*Oc1ccc(C(=O)OC(=O)c2cccc(O*)cc2)cc1C)cc1'
# [21:24:25] SMILES Parse Error: unclosed ring for input: '*c1ccc(*)c(C(F)(F)C(*)(F)C(F)(F)F)c(F)F'
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *c1ccc(COC(=O)c2cc(C)c3ccc(C(=O)OCCCCCCCOc4ccc(-c5nnc(*)o4c3)cccc2o1)c1
# [21:24:25] SMILES Parse Error: check for mistakes around position
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *CCCCCCCCNC(=O)OCC(OC)C(OC)(OC)C(OC(=O)N*
# [21:24:25] SMILES Parse Error: check for mistakes around position 33:
# [21:24:25] =O)OCC(OC)C(OC)(OC)C(OC(=O)N*
# [21:24:25] ~~~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*CCCCCCCCNC(=O)OCC(OC)C(OC)(OC)C(OC(=O)N*' for input: '*CCCCCCCCNC(=O)OCC(OC)C(OC)(OC)C(OC(=O)N*'
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *OC(C)S(Cc1cccc1C
# [21:24:25] SMILES Parse Error: check for mistakes around position 8:
# [21:24:25] *OC(C)S(Cc1cccc1C
# [21:24:25] ~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*OC(C)S(Cc1cccc1C' for input: '*OC(C)S(Cc1cccc1C'
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *OC(C)COC(=O)OC(*)C(OC(C)=O
# [21:24:25] SMILES Parse Error: check for mistakes around position 20:
# [21:24:25] *OC(C)COC(=O)OC(*)C(OC(C)=O
# [21:24:25] ~~~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*OC(C)COC(=O)OC(*)C(OC(C)=O' for input: '*OC(C)COC(=O)OC(*)C(OC(C)=O'
# [21:24:25] SMILES Parse Error: syntax error while parsing: *O[Si](C)(C)c1cccc((OC(=O)OCNC(*)CC)cc1
# [21:24:25] SMILES Parse Error: check for mistakes around position 20:
# [21:24:25] *O[Si](C)(C)c1cccc((OC(=O)OCNC(*)CC)cc1
# [21:24:25] ~~~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*O[Si](C)(C)c1cccc((OC(=O)OCNC(*)CC)cc1' for input: '*O[Si](C)(C)c1cccc((OC(=O)OCNC(*)CC)cc1'
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *=*Oc1ccc(NC(=O)c2ccc(Sc3c(c2cccc(S(*)(=O)=O)cc2)c1
# [21:24:25] SMILES Parse Error: check for mistakes around position 10:
# [21:24:25] *=*Oc1ccc(NC(=O)c2ccc(Sc3c(c2cccc(S(*)(=O
# [21:24:25] ~~~~~~~~~^
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *=*Oc1ccc(NC(=O)c2ccc(Sc3c(c2cccc(S(*)(=O)=O)cc2)c1
# [21:24:25] SMILES Parse Error: check for mistakes around position 22:
# [21:24:25] =*Oc1ccc(NC(=O)c2ccc(Sc3c(c2cccc(S(*)(=O)
# [21:24:25] ~~~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*=*Oc1ccc(NC(=O)c2ccc(Sc3c(c2cccc(S(*)(=O)=O)cc2)c1' for input: '*=*Oc1ccc(NC(=O)c2ccc(Sc3c(c2cccc(S(*)(=O)=O)cc2)c1'
# [21:24:25] SMILES Parse Error: unclosed ring for input: '*C(=O)Nc2cccc(-c3ccc(-c4ccc(Oc5ccc(Oc6cccc(*)n6c5)cc4)cc3)c2)cc1'
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *O/N=C/C(C)=N/c1ccc(C(=O)OCCCCCO*Ccc1
# [21:24:25] SMILES Parse Error: check for mistakes around position 20:
# [21:24:25] *O/N=C/C(C)=N/c1ccc(C(=O)OCCCCCO*Ccc1
# [21:24:25] ~~~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*O/N=C/C(C)=N/c1ccc(C(=O)OCCCCCO*Ccc1' for input: '*O/N=C/C(C)=N/c1ccc(C(=O)OCCCCCO*Ccc1'
# [21:24:25] Can't kekulize mol.  Unkekulized atoms: 20 21 22 23 25
# [21:24:25] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 17 18 19
# [21:24:25] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 5 6 7 49 50
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *Oc1ccc(-c2ccc(OC(=O)c3ccc(C(=O)Oc4ccc(C4(*)OC4(=O)NCC3=O)cc2)cc1
# [21:24:25] SMILES Parse Error: check for mistakes around position 8:
# [21:24:25] *Oc1ccc(-c2ccc(OC(=O)c3ccc(C(=O)Oc4ccc(C4
# [21:24:25] ~~~~~~~^
# [21:24:25] SMILES Parse Error: extra open parentheses while parsing: *Oc1ccc(-c2ccc(OC(=O)c3ccc(C(=O)Oc4ccc(C4(*)OC4(=O)NCC3=O)cc2)cc1
# [21:24:25] SMILES Parse Error: check for mistakes around position 15:
# [21:24:25] *Oc1ccc(-c2ccc(OC(=O)c3ccc(C(=O)Oc4ccc(C4
# [21:24:25] ~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*Oc1ccc(-c2ccc(OC(=O)c3ccc(C(=O)Oc4ccc(C4(*)OC4(=O)NCC3=O)cc2)cc1' for input: '*Oc1ccc(-c2ccc(OC(=O)c3ccc(C(=O)Oc4ccc(C4(*)OC4(=O)NCC3=O)cc2)cc1'
# [21:24:25] SMILES Parse Error: syntax error while parsing: *CCCCCCCCCCCCCCCCCCCCCCCCCOC(=O)CC/CC=C/C1CCC(7CCC(=O)N*)C2=CCC12
# [21:24:25] SMILES Parse Error: check for mistakes around position 47:
# [21:24:25] OC(=O)CC/CC=C/C1CCC(7CCC(=O)N*)C2=CCC12
# [21:24:25] ~~~~~~~~~~~~~~~~~~~~^
# [21:24:25] SMILES Parse Error: Failed parsing SMILES '*CCCCCCCCCCCCCCCCCCCCCCCCCOC(=O)CC/CC=C/C1CCC(7CCC(=O)N*)C2=CCC12' for input: '*CCCCCCCCCCCCCCCCCCCCCCCCCOC(=O)CC/CC=C/C1CCC(7CCC(=O)N*)C2=CCC12'
# [21:24:25] non-ring atom 2 marked aromatic

# %%
chems = [Chem.MolFromSmiles(x) for x in valid_smiles]
mols2grid.display(chems)
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %%
valid_smiles
# Out:
# ['',
#  '*CC(*)c1ccc2ccccc2c1',
#  '*c1ccc(OC(=O)c2cc(C(=O)Oc3ccc(C4(*)NC(=O)c5ccccc54)cc3)c2)cc1',
#  '*CC(*)c1cccc(C)c1',
#  '*CCCCCCCC(=O)N*',
#  '*CCN(*)C(=O)c1ccccc1',
#  '*C(=O)OCCCCCCCCCCCCCCCOC(=O)c1cccc(C(=O)OC(=O)c2ccc(O*)cc2)c1',
#  '*CCCCCCC(=O)N*',
#  '*CCC(*)(C)C(=O)OCCOC(C)(CC)C',
#  '*Oc1ccc(C(C)c2ccc(OC(=O)c3ccc(C(*)=O)cc3)cc2)cc1',
#  '*C(=O)Nc1ccc(Oc2ccccc(NC(=O)c3c(C(=O)c4ccc(Oc5ccc(Oc6ccc(N7C(=O)c8ccc(*)cc8C7=O)cc6)cc5)cc3)C4=O)cc2)cc1',
#  '*CCCO*',
#  '*C(=O)N*',
#  '*Oc1ccc(NC(=O)CCCCC(=O)Nc2ccc(*)cc2)cc1',
#  '*CCS*',
#  '*CC(CSCC)OC(=O)OCCCCC',
#  '*N(*)C(=O)CCCC',
#  '*CCOC(=O)c2ccccc2C(=O)OCCCCCOc1ccc(-c2ccc(O*)cc2)cc1',
#  '*Nc1ccc(CCC(=O)OCCCCOC(=O)c2ccc(*)cc2)cc1',
#  '*CCCC(=O)O*',
#  '*CC(*)CCCCCCCCCCCCCCCC',
#  '*CC(*)CCCC1CCCCC1',
#  '*CCCCCOC(=O)NCC(C)C(=O)O*',
#  '*Oc1ccc(C(C)(C)c2ccc(OC(*)=O)cc2)cc1',
#  '*CCS*',
#  '*CCCCOC(=O)OCCCCCOC(=O)O*',
#  '*CC(C)(C)CO*',
#  '*CCCCCCC(=O)O*',
#  '*COc1ccc(C(=O)OCCCCOC(=O)c2ccc(O*)cc2)c(C)c1',
#  '*CC(*)(C)C(=O)OCCCCCCCCCCOc1ccc(C(=O)Oc2ccc(C(=O)/C=C/c3cc(O*)ccc3)cc2)cc1',
#  '*=CCCC(CC)(C)CO*',
#  '*CCOC(=O)c1ccc(C(=O)O*)cc1',
#  '*Oc1ccc(NC(=O)CCCCCCCCCC(=O)Nc2ccc(*)cc2)cc1',
#  '*CCCN(*)C(=O)c1ccccc1',
#  '*O[Si](*)(C)CCCCOc1ccc(C(=O)OC*)cc1',
#  '*CCCCCCCOC(=O)Nc1ccc(Cc2ccc(NC(=O)O*)cc2)cc1',
#  '*CCCCCCOC(=O)OC*',
#  '*CC(F)(F)C(F)(F)C(F)(F)C(F)(F)COC(F)(F)C(F)(F)C(F)(F)CNC(=O)OCCCCC(=O)N*',
#  '*CCCCC(C)(C)C',
#  '*CC(*)C(=O)O',
#  '*Nc1ccc(Cc2ccc(NC(=O)CCCCCCC(*)=O)cc2)cc1',
#  '*Cc1ccc(C(=O)NCCCCCCCC(=O)N*)cc1',
#  '*CCCCC(=O)N(N*)C(=O)C(OC)CS(C)(=O)=O']
